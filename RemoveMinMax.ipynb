# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('price_recommendation.csv')

# %%
df
# Out:
#             State            District                         Market  \
# 0      Chandigarh          Chandigarh        Chandigarh(Grain/Fruit)
# 1      Chandigarh          Chandigarh        Chandigarh(Grain/Fruit)
# 2      Chandigarh          Chandigarh        Chandigarh(Grain/Fruit)
# 3      Chandigarh          Chandigarh        Chandigarh(Grain/Fruit)
# 4         Haryana              Hissar                          Hansi
# ...           ...                 ...                            ...
# 1191  West Bengal             Hooghly                    Sheoraphuly
# 1192  West Bengal          Jalpaiguri               Jalpaiguri Sadar
# 1193  West Bengal          Jalpaiguri               Jalpaiguri Sadar
# 1194  West Bengal               Malda                  English Bazar
# 1195  West Bengal  Sounth 24 Parganas  Diamond Harbour(South 24-pgs)
#
#                        Commodity         Variety   Grade Arrival_Date  \
# ...

# %%
df.drop(columns = ['Variety','Grade','Arrival_Date'])
# Out:
#             State            District                         Market  \
# 0      Chandigarh          Chandigarh        Chandigarh(Grain/Fruit)
# 1      Chandigarh          Chandigarh        Chandigarh(Grain/Fruit)
# 2      Chandigarh          Chandigarh        Chandigarh(Grain/Fruit)
# 3      Chandigarh          Chandigarh        Chandigarh(Grain/Fruit)
# 4         Haryana              Hissar                          Hansi
# ...           ...                 ...                            ...
# 1191  West Bengal             Hooghly                    Sheoraphuly
# 1192  West Bengal          Jalpaiguri               Jalpaiguri Sadar
# 1193  West Bengal          Jalpaiguri               Jalpaiguri Sadar
# 1194  West Bengal               Malda                  English Bazar
# 1195  West Bengal  Sounth 24 Parganas  Diamond Harbour(South 24-pgs)
#
#                        Commodity  Min_x0020_Price  Max_x0020_Price  \
# 0                    Cauliflower             1500             2200
# ...

# %%
state = 'Maharashtra'
district='Buldhana'
market = 'Deoulgaon Raja'

# %%
query = df[(df['State'] == state) & (df['District']== district) & (df['Market'] == market)]

# %%
query
# Out:
# Empty DataFrame
# Columns: [State, District, Market, Commodity, Variety, Grade, Arrival_Date, Min_x0020_Price, Max_x0020_Price, Modal_x0020_Price]
# Index: []

# %%
filtered_data = df[(df['State'] == 'Maharashtra') & (df['District'] == 'Pune') & (df['Market'] == 'Pune') & (df['Commodity'] == 'Garlic')]

min_price = filtered_data['Min_x0020_Price'].values
max_price = filtered_data['Max_x0020_Price'].values

print(f"The corresponding minimum price is : {min_price}")
print(f"The corresponding maximum price is : {max_price}")
# Out:
# The corresponding minimum price is : [5000]
# The corresponding maximum price is : [12000]

# %%
filtered_data
# Out:
#             State District Market Commodity Variety Grade Arrival_Date  \
# 1048  Maharashtra     Pune   Pune    Garlic   Other   FAQ   24-03-2024
#
#       Min_x0020_Price  Max_x0020_Price  Modal_x0020_Price
# 1048             5000            12000               8500
